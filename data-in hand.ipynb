# %%
import pandas as pd

# %%
gsheet_id = "1Wxd44H7vu9_E16sNpeRAkcpVZAoE62xzOu75Wg3xiwk"

# %%
df = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{gsheet_id}/export?format=csv")
df.head()
# Out:
#                            Title         Author Secondary Author  \
# 0                        #Hockey   Ukazu, Ngozi              NaN
# 1                        #Hockey   Ukazu, Ngozi              NaN
# 2  10 Things I Can See from Here    Mac, Carrie              NaN
# 3                 10,000 Dresses  Ewert, Marcus              NaN
# 4                 10,000 Dresses  Ewert, Marcus              NaN
#
#   Illustrator(s) Translators(s)     Series Name    State  \
# 0            NaN            NaN  Check, Please!    Texas
# 1            NaN            NaN  Check, Please!  Florida
# 2            NaN            NaN             NaN  Florida
# 3       Ray, Rex            NaN             NaN  Florida
# 4       Ray, Rex            NaN             NaN  Florida
#
#                              District Date of Challenge  \
# 0  Frisco Independent School District     November 2022
# 1         Clay County School District      AY 2022-2023
# 2      Escambia County Public Schools         June 2023
# 3         Clay County School District      AY 2022-2023
# 4      Seminole County Public Schools         July 2022
#
#                              Ban Status              Origin of Challenge
# 0  Banned from Libraries and Classrooms               Informal Challenge
# 1          Banned Pending Investigation  Administration/Formal Challenge
# 2          Banned Pending Investigation                 Formal Challenge
# 3          Banned Pending Investigation  Administration/Formal Challenge
# 4                 Banned from Libraries                 Formal Challenge

# %% [markdown]
# I collected this data from the PEN America Index of School Book Bans from the 2022-2023 school year. It is originally a searchable index on the webpage, but you can gain access and download it through a google sheet. I first got to the google sheet and then made my own copy. I had to change the sharing settings to be able to use it on this notebook and then I used the sheet ID and link and changed the format to a csv file. I also had to edit the sheet because the sheet did not have the columns labeled like the index did on the page.
